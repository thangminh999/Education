-- %% [markdown]
-- # [dbo].[Account]

-- %%
USE [ReviewDatabase]
GO

-- %%
/****** Object:  Table [dbo].[Account]    Script Date: 4/29/2022 10:20:00 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Account](
	[AccountName] [nvarchar](100) NOT NULL,
	[Password] [nvarchar](100) NOT NULL,
	[FullName] [nvarchar](100) NOT NULL,
	[Email] [nvarchar](100) NULL,
	[Tell] [nvarchar](200) NULL,
	[DateCreated] [smalldatetime] NULL,
 CONSTRAINT [PK_Account] PRIMARY KEY CLUSTERED 
(
	[AccountName] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BillDetails]

-- %%
/****** Object:  Table [dbo].[BillDetails]    Script Date: 4/29/2022 10:20:00 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BillDetails](
	[ID] [int] NOT NULL,
	[InvoiceID] [int] NOT NULL,
	[FoodID] [int] NOT NULL,
	[Quanlity] [int] NOT NULL,
 CONSTRAINT [PK_BillDetails] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Bills]

-- %%
/****** Object:  Table [dbo].[Bills]    Script Date: 4/29/2022 10:20:00 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Bills](
	[ID] [int] NOT NULL,
	[Name] [nvarchar](100) NOT NULL,
	[Amount] [int] NOT NULL,
	[TableID] [int] NOT NULL,
	[Discount] [float] NULL,
	[Tax] [float] NULL,
	[Status] [bit] NOT NULL,
	[CheckoutDate] [smalldatetime] NULL,
	[Account] [nvarchar](100) NOT NULL,
 CONSTRAINT [PK_Bills] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Catagory]

-- %%
/****** Object:  Table [dbo].[Catagory]    Script Date: 4/29/2022 10:20:00 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Catagory](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](1000) NOT NULL,
	[Type] [int] NOT NULL,
 CONSTRAINT [PK_Catagory] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Food]

-- %%
/****** Object:  Table [dbo].[Food]    Script Date: 4/29/2022 10:20:00 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Food](
	[ID] [int] NOT NULL,
	[Name] [nvarchar](50) NOT NULL,
	[Unit] [nvarchar](100) NOT NULL,
	[FoodCatagoryID] [int] NOT NULL,
	[Price] [int] NOT NULL,
	[Notes] [nvarchar](100) NULL,
 CONSTRAINT [PK_Food] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Role]

-- %%
/****** Object:  Table [dbo].[Role]    Script Date: 4/29/2022 10:20:00 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Role](
	[ID] [int] NOT NULL,
	[RoleName] [nvarchar](3000) NOT NULL,
	[Path] [nvarchar](3000) NULL,
	[Notes] [nvarchar](3000) NULL,
 CONSTRAINT [PK_Role] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RoleAccount]

-- %%
/****** Object:  Table [dbo].[RoleAccount]    Script Date: 4/29/2022 10:20:00 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RoleAccount](
	[RoleID] [int] NOT NULL,
	[Account] [nvarchar](100) NOT NULL,
	[Actived] [int] NOT NULL,
	[Notes] [nvarchar](100) NULL,
 CONSTRAINT [PK_RoleAccount] PRIMARY KEY CLUSTERED 
(
	[RoleID] ASC,
	[Account] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TableFood]

-- %%
/****** Object:  Table [dbo].[TableFood]    Script Date: 4/29/2022 10:20:00 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TableFood](
	[ID] [int] NOT NULL,
	[Name] [nvarchar](100) NULL,
	[Status] [int] NOT NULL,
	[Capacity] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Account]

-- %%
INSERT [dbo].[Account] ([AccountName], [Password], [FullName], [Email], [Tell], [DateCreated]) VALUES (N'hoaiphong', N'phongne123', N'phongne123', N'hoaiphong01012002@gmail.com', NULL, NULL)
INSERT [dbo].[Account] ([AccountName], [Password], [FullName], [Email], [Tell], [DateCreated]) VALUES (N'jztr', N'jztr', N'jztr', N'jztr', NULL, NULL)
INSERT [dbo].[Account] ([AccountName], [Password], [FullName], [Email], [Tell], [DateCreated]) VALUES (N'vananh', N'anhne123', N'anhne123', N'vananh2111', N'', NULL)
GO

-- %% [markdown]
-- # [dbo].[Catagory]

-- %%
SET IDENTITY_INSERT [dbo].[Catagory] ON 
INSERT [dbo].[Catagory] ([ID], [Name], [Type]) VALUES (1, N'Tráng miệng', 1)
INSERT [dbo].[Catagory] ([ID], [Name], [Type]) VALUES (2, N'Món rau', 1)
SET IDENTITY_INSERT [dbo].[Catagory] OFF
GO

-- %% [markdown]
-- # [FK_BillDetails_Food]

-- %%
ALTER TABLE [dbo].[BillDetails]  WITH CHECK ADD  CONSTRAINT [FK_BillDetails_Food] FOREIGN KEY([InvoiceID])
REFERENCES [dbo].[Food] ([ID])
GO
ALTER TABLE [dbo].[BillDetails] CHECK CONSTRAINT [FK_BillDetails_Food]
GO

-- %% [markdown]
-- # [FK_RoleAccount_Account]

-- %%
ALTER TABLE [dbo].[RoleAccount]  WITH CHECK ADD  CONSTRAINT [FK_RoleAccount_Account] FOREIGN KEY([Account])
REFERENCES [dbo].[Account] ([AccountName])
GO
ALTER TABLE [dbo].[RoleAccount] CHECK CONSTRAINT [FK_RoleAccount_Account]
GO

-- %% [markdown]
-- # [FK_RoleAccount_Role]

-- %%
ALTER TABLE [dbo].[RoleAccount]  WITH CHECK ADD  CONSTRAINT [FK_RoleAccount_Role] FOREIGN KEY([RoleID])
REFERENCES [dbo].[Role] ([ID])
GO
ALTER TABLE [dbo].[RoleAccount] CHECK CONSTRAINT [FK_RoleAccount_Role]
GO

-- %% [markdown]
-- # [FK_Table_Bills]

-- %%
ALTER TABLE [dbo].[TableFood]  WITH CHECK ADD  CONSTRAINT [FK_Table_Bills] FOREIGN KEY([Capacity])
REFERENCES [dbo].[Bills] ([ID])
GO
ALTER TABLE [dbo].[TableFood] CHECK CONSTRAINT [FK_Table_Bills]
GO

-- %% [markdown]
-- # [dbo].[Catagory_GetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[Catagory_GetAll]    Script Date: 4/29/2022 10:20:00 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 create proc [dbo].[Catagory_GetAll]
as
begin
	select * from dbo.Catagory
end
GO

-- %% [markdown]
-- # [dbo].[Catagory_GetAllId]

-- %%
/****** Object:  StoredProcedure [dbo].[Catagory_GetAllId]    Script Date: 4/29/2022 10:20:00 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Catagory_GetAllId]
( @ID int )
as
begin
	select * from dbo.Catagory where ID = @ID
end
GO

-- %% [markdown]
-- # [dbo].[Category_Delete]

-- %%
/****** Object:  StoredProcedure [dbo].[Category_Delete]    Script Date: 4/29/2022 10:20:00 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- Category Delete
create proc [dbo].[Category_Delete]
(
	@ID int
)
as
begin
		delete from dbo.Catagory
		where ID=@ID
end
GO

-- %% [markdown]
-- # [dbo].[Category_Insert]

-- %%
/****** Object:  StoredProcedure [dbo].[Category_Insert]    Script Date: 4/29/2022 10:20:00 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[Category_Insert]
(
@ID int output,
@Name nvarchar(1000),
@Type int
)
as
begin
	-- kiểm tra tồn tại Name
	if ( not exists ( select Name from dbo.Catagory where Name=@Name))
		insert into dbo.Catagory(Name,Type) values (@Name,@Type)
		set @ID=@@IDENTITY
end
GO

-- %% [markdown]
-- # [dbo].[Category_UPdate]

-- %%
/****** Object:  StoredProcedure [dbo].[Category_UPdate]    Script Date: 4/29/2022 10:20:00 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Category_UPdate]
(
@ID int,
@Name nvarchar(100),
@Type int
)
as
begin
	update dbo.Catagory
	set [Name]=@Name,[Type]=@Type
	where ID=@ID
end
GO

-- %% [markdown]
-- # [dbo].[Getall]

-- %%
/****** Object:  StoredProcedure [dbo].[Getall]    Script Date: 4/29/2022 10:20:00 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Getall]
( 
	@Table nvarchar(200)
)
as
begin
	declare @Sql nvarchar(100)
	set @sql = 'Select * from ' + @Table
	exec (@sql) -- thực thi
end
GO
